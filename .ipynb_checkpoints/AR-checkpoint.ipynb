# %%
import numpy as np
from scipy.stats import pearsonr
import scipy.signal as ss
import scipy.stats as scst
import saffy
from saffy.generators.svarog import svarog
import matplotlib.pyplot as plt
from scipy import signal
import mtmvar

# %%
saffy.__version__
# Out:
# '0.1.12-dev2'

# %%
fig = plt.figure(figsize = (50,20))

pliki = {'open':'mateusz_oczy_szeroko_zamkniete', 'closed':'mateusz_oczy_zamkniete', 'inne':'mateusz_try1'}

EEG2 = saffy.SignalManager(generator=svarog(pliki['closed']))
CH = ['Fp1', 'P3', 'Pz', 'P4', 'Fp2', 'O1', 'O2','A1','A2']
EEG2.butter_highpass_filter(cutoff=1, order=5, method=None)
EEG2.extract_channels(CH)
EEG_2D_F = EEG2.data[0,:,:] #jest tylko jeden zestaw danych
EEG_2D_F = EEG_2D_F - (EEG_2D_F[-1,:] + EEG_2D_F[-2,:])/2 #montaz - średnia z uszu   
EEG_2D_F = EEG_2D_F[0:-2,:] #usuwamy kanały uszne
# Out:
# 2019-12-18 20:19:12,058 - data_source - INFO - All data set requested for the first time. Start reading all data from the file...

# %%
syg1 = EEG_2D_F[0,:1000]
fig = plt.figure(figsize = (25,5))
plt.plot(syg1, linewidth=4)
plt.show()

# %%
len(syg1.shape)
# Out:
# 1

# %%
syg1 = np.reshape(syg1,(1,-1))
syg1.shape
# Out:
# (1, 1000)

# %%
mtmvar.mult_AR(syg1, 1, 1)
# Out:
# (array([[[0.94635811]]]), array([[17.25224365]]))

# %%
AR = []
for i in range(1,6):
    AR.append(mtmvar.mult_AR(syg1, i, 1))
AR
# Out:
# [(array([[[0.94635811]]]), array([[17.25224365]])), (array([[[ 1.26261029]],
#
#          [[-0.33417813]]]), array([[15.32559899]])), (array([[[ 1.22087409]],
#
#          [[-0.1764881 ]],
#
#          [[-0.12489208]]]), array([[15.0865498]])), (array([[[ 1.1928911 ]],
#
#          [[-0.21603155]],
#
#          [[ 0.14865371]],
#
#          [[-0.22405733]]]), array([[14.32917952]])), (array([[[ 1.16098011]],
#
#          [[-0.19485979]],
#
#          [[ 0.11788577]],
#
#          [[-0.05416178]],
#
#          [[-0.14242336]]]), array([[14.03852054]]))]

# %%
def AIC(syg, min_order, max_order):
    if len(syg.shape) == 1:
        syg = np.reshape(syg,(1,-1))
    aic = np.zeros(max_order-min_order+1)
    k = syg.shape[0]
    N = syg.shape[1]
    for i, p in enumerate(range(min_order, max_order+1)):
        params, V = mtmvar.mult_AR(syg, p, 1)
        aic[i] = np.log(np.linalg.det(V)) + 2*p*k**2/N
    return aic

# %%
aic = AIC(syg1, 1, 20)

# %%
fig = plt.figure(figsize = (15,5))
plt.xticks(np.arange(1, 21, step=2))
plt.plot(np.arange(1,21), aic, linewidth=4)
plt.show()

# %%
def model_transform(syg, p, f_min, f_max):
    if len(syg.shape) == 1:
        syg = np.reshape(syg,(1,-1))
    Azz = []
    for f in range(1, int(EEG2.fs/2)):
        A, V = mtmvar.mult_AR(syg, p, 1)
        Az = np.sum(A * np.exp(2*np.pi*f*(1/EEG2.fs))**np.arange(0,-p,-1).reshape((-1,1,1)), axis=0)
#  0.67895728 0.6780434  0.67715093 0.67627934 0.67542813 0.6745968
#  0.67378487 0.67299187 0.67221737 0.67146091 0.67072208 0.67000045
#  0.66929563 0.66860722 0.66793485 0.66727813 0.6666367  0.66601022
#  0.66539833 0.66480071 0.66421701 0.66364692 0.66309014 0.66254634
#  0.66201524 0.66149654 0.66098996 0.66049523 0.66001206 0.65954019
#  0.65907938 0.65862935 0.65818987 0.65776069 0.65734158 0.65693231
#  0.65653265 0.65614238 0.65576128 0.65538914 0.65502577 0.65467094
#  0.65432448]
# [1.55795964 1.52877612 1.50010858 1.47347563 1.44951692 1.42836821
#  1.40989987 1.39385893 1.37994958 1.36787617 1.35736446 1.34817049
#  1.34008276 1.33292094 1.32653297 1.3207916  1.31559086 1.31084283
#  1.30647471 1.3024263  1.29864787 1.29509835 1.29174382 1.28855625
#  1.28551252 1.28259352 1.27978345 1.27706928 1.27444024 1.27188744
#  1.26940354 1.26698251 1.26461935 1.26230997 1.260051   1.25783965
#  1.25567365 1.25355112 1.25147052 1.24943058 1.24743023 1.24546859
#  1.24354493 1.2416586  1.23980907 1.23799585 1.2362185  1.23447663
#  1.23276986 1.23109783 1.22946018 1.22785656 1.22628662 1.22475
#  1.22324632 1.22177522 1.22033629 1.21892914 1.21755335 1.2162085
#  1.21489416 1.21360987 1.21235518 1.21112962 1.20993273 1.20876402
#  1.207623   1.20650918 1.20542207 1.20436116 1.20332597 1.20231597
#  1.20133068 1.20036959 1.19943219 1.198518   1.19762652 1.19675724
#  1.19590969 1.19508339 1.19427784 1.19349259 1.19272716 1.19198109
#  1.19125393 1.19054523 1.18985454 1.18918145 1.18852551 1.18788632
#  1.18726345 1.18665652 1.18606512 1.18548887 1.18492738 1.18438029
#  1.18384724 1.18332786 1.18282181 1.18232875 1.18184836 1.18138029
#  1.18092425 1.18047991 1.18004698 1.17962516 1.17921417 1.17881372
#  1.17842354 1.17804336 1.17767293 1.17731198 1.17696028 1.17661759
#  1.17628366 1.17595826 1.17564119 1.17533221 1.17503112 1.17473771
#  1.17445179 1.17417315 1.1739016  1.17363697 1.17337907 1.17312772
#  1.17288276]

# %%
A = model_transform(syg3,9,0,1)
f = 1
A * np.exp(2*np.pi*f*(1/EEG2.fs))**np.arange(0,-9,-1).reshape((-1,1,1))

# np.dot(A,(np.exp(2*np.pi*f*(1/EEG2.fs))**np.arange(-1,-9-1,-1)).reshape((-1,1,1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-6f986729749a> in <module>()
#       1 A = model_transform(syg3,9,0,1)
#       2 f = 1
# ----> 3 A * np.exp(2*np.pi*f*(1/EEG2.fs))**np.arange(0,-9,-1).reshape((-1,1,1))
#       4
#       5 # np.dot(A,(np.exp(2*np.pi*f*(1/EEG2.fs))**np.arange(-1,-9-1,-1)).reshape((-1,1,1)))
#
# ValueError: operands could not be broadcast together with shapes (127,3,3) (9,1,1)

# %%
A[-1] * np.exp(2*np.pi*f*(1/EEG2.fs))**(-8)
# Out:
# array([[ 0.92165347, -0.1502721 ,  0.1834165 ],
#        [-0.0103059 ,  1.0642076 , -0.19456658],
#        [ 0.09528529, -0.12062389,  0.79963647]])

# %%
(np.exp(2*np.pi*f*(1/EEG2.fs))**np.arange(-1,-4-1,-1)).shape
# Out:
# (4,)

# %%
one = np.ones((3,3,3))

# %%
np.dot(one, np.arange(1,4)**(-np.ones(3)))
# Out:
# array([[1.83333333, 1.83333333, 1.83333333],
#        [1.83333333, 1.83333333, 1.83333333],
#        [1.83333333, 1.83333333, 1.83333333]])

# %%
f = np.arange(1, int(EEG2.fs/2))
p=5
A, V = mtmvar.mult_AR(syg3, p, 1)

z = np.exp(2*np.pi*1j*f*(1/EEG2.fs))**np.arange(0,-p,-1).reshape((-1,1,1))
# print(z.shape)
# z = np.squeeze(z).reshape((z.shape[-1],z.shape[0]))
z = np.squeeze(z).T
print(z.shape , A.shape)
Az = np.tensordot(z , A , axes=1)

Az = np.swapaxes(Az, 0, 2)
Az = np.swapaxes(Az, 0, 1)
print(Az.shape)
# Az = np.reshape(Az,(Az.shape[-1],Az.shape[1],Az.shape[0]))
H = np.linalg.inv(Az.T).T
# print(H.shape)
# H = np.reshape(H,(H.shape[-1],H.shape[1],H.shape[0]))
# print(H.shape)
H = np.swapaxes(H, 0, 1)
H = np.swapaxes(H, 0, 2)

for i in range(3):
    plt.plot(H[:,i,i]*np.conj(H[:,i,i]))
plt.show()

widmo = np.abs(np.fft.rfft(syg3[0]))
freq = np.fft.rfftfreq(len(syg3[0]),1/EEG2.fs)
plt.plot(freq,widmo)
# plt.xlim
plt.show()
# Out:
# (127, 5) (5, 3, 3)
# (3, 3, 127)
# /home/beatka/.local/lib/python3.7/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
X = np.array([np.array([[1,2,3], [1,2,3], [1,2,3]]),np.array([[1,2,3], [1,2,3], [1,2,3]])]
# Out:
#   File "<ipython-input-172-3dbe1ed45d76>", line 1
#     X = np.array([np.array([[1,2,3], [1,2,3], [1,2,3]]),np.array([[1,2,3], [1,2,3], [1,2,3]])]
#                                                                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
X = np.swapaxes(X, 0, 2)

# %%
X
# Out:
# array([[[1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3]],
#
#        [[1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3]]])

# %%
freqz = np.arange(1, int(EEG2.fs/2))
p=5
ch=3
A_all, V = mtmvar.mult_AR(syg3, p, 1)
print(V.shape)
X_pseudo = np.zeros((len(freqz),ch,ch))
for ind,fr in enumerate(freqz):
    A_temp = np.zeros((p,A_all.shape[1],A_all.shape[2]))
    for p_prim in range(p):
        z = np.exp(2*np.pi*1j*fr*1/EEG2.fs*(-p_prim))
        A_temp[p_prim] = A[p_prim]*z
    Az = np.sum(A_temp,axis=0)
    #shape = 3,3
    Az_inv = np.linalg.inv(Az)
    X_pseudo[ind,:,:] = Az_inv
S_pseudo = X_pseudo*np.conj(X_pseudo)
for i in range(ch):
    plt.plot(S_pseudo[:,i,i])
plt.show()

for i in range(3):
    plt.plot(H[:,i,i]*np.conj(H[:,i,i]).T)
plt.show()
# Out:
# (3, 3)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: ComplexWarning: Casting complex values to real discards the imaginary part
#   # This is added back by InteractiveShellApp.init_path()
# (127,)
# /home/beatka/.local/lib/python3.7/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
